# %%
#import statements
import base64
import datetime
from urllib.parse import urlencode
import requests
import json
import csv

# %%
#Spotify API Client Object (SAPICO) definition
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        Returns a base64 encoded string (not bytes)
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}" #<base64 encoded client_id:client_secret>
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
#Accessed Spotify Endpoint: albums (https://developer.spotify.com/documentation/web-api/reference/albums/)
    
    def get_album_data(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
#Accessed Spotify Endpoint: artists (https://developer.spotify.com/documentation/web-api/reference/artists/)
    
    def get_artist_data(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def get_artist_genres(self, _id):
        return self.get_artist_data(_id)['genres']
    
#Accessed Spotify Endpoint: tracks (https://developer.spotify.com/documentation/web-api/reference/tracks/)
    
    def get_track_data(self, _id):
        return self.get_resource(_id, resource_type='tracks')
    
    def get_track_artists(self, _id):
        return self.get_track_data(_id)['artists']
    
    #UPDATE with iteration for multiple artists
    def get_track_artists_id(self, _id):
        return self.get_track_artists(_id)[0]['id']
    
    #Spotify API reference link: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/
    
    def get_track_audio_features(self, _id):
        return self.get_resource(_id, resource_type='audio-features')
    
    def get_track_specific_audio_feature(self, _id, specific_audio_feature='tempo'):
        return self.get_track_audio_features(_id)[specific_audio_feature]
    
#Accessed Spotify Endpoint: search (https://developer.spotify.com/documentation/web-api/reference/search/search/)
    
    def base_search(self, query_params): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        #OR or NOT are two operators
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower()})
        print(query_params)
        return self.base_search(query_params)

# %%
#instantiate Spotify API client object
client_id = '' # '' = your client_id
client_secret = '' # '' = your client_secret
spotify = SpotifyAPI(client_id, client_secret)

# %%
#Andy Williams artistID: 4sj6D0zlMOl25nprDJBiU9
spotify.get_artist_data("4sj6D0zlMOl25nprDJBiU9")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4sj6D0zlMOl25nprDJBiU9'},
#  'followers': {'href': None, 'total': 326683},
#  'genres': ['adult standards', 'easy listening', 'mellow gold'],
#  'href': 'https://api.spotify.com/v1/artists/4sj6D0zlMOl25nprDJBiU9',
#  'id': '4sj6D0zlMOl25nprDJBiU9',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/cd88f73a20d4760a44e0e4f2378eefa9b1a0910e',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/4f44f5575e79e472e2078f95ec9e78768658250d',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/395d1258d17a0bd2bbead87dba510041c52ed4fa',
#    'width': 160}],
#  'name': 'Andy Williams',
#  'popularity': 81,
#  'type': 'artist',
#  'uri': 'spotify:artist:4sj6D0zlMOl25nprDJBiU9'}

# %%
spotify.search({"track": "Navajo"}, search_type="track")
# Out:
# q=track%3ANavajo&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ANavajo&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ycxRkcZ67ALN3GQJ57Vig'},
#        'href': 'https://api.spotify.com/v1/artists/3ycxRkcZ67ALN3GQJ57Vig',
#        'id': '3ycxRkcZ67ALN3GQJ57Vig',
#        'name': 'Masego',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ycxRkcZ67ALN3GQJ57Vig'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5DxMTCWwHlaz4Hx1og50xL'},
#      'href': 'https://api.spotify.com/v1/albums/5DxMTCWwHlaz4Hx1og50xL',
#      'id': '5DxMTCWwHlaz4Hx1og50xL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27328f137f2d8bda3ddd5d045cf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0228f137f2d8bda3ddd5d045cf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485128f137f2d8bda3ddd5d045cf',
#        'width': 64}],
#      'name': 'Navajo',
#      'release_date': '2017-06-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5DxMTCWwHlaz4Hx1og50xL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ycxRkcZ67ALN3GQJ57Vig'},
#       'href': 'https://api.spotify.com/v1/artists/3ycxRkcZ67ALN3GQJ57Vig',
#       'id': '3ycxRkcZ67ALN3GQJ57Vig',
#       'name': 'Masego',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ycxRkcZ67ALN3GQJ57Vig'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194157,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM24S1702110'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6zWU7YALeEDMcPGhKKZJhV'},
#     'href': 'https://api.spotify.com/v1/tracks/6zWU7YALeEDMcPGhKKZJhV',
#     'id': '6zWU7YALeEDMcPGhKKZJhV',
#     'is_local': False,
#     'name': 'Navajo',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/18efa064300447678b2e14861d41eaffa190ea8d?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6zWU7YALeEDMcPGhKKZJhV'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3M2S7bYzQt6h4KrnoihzLS'},
#        'href': 'https://api.spotify.com/v1/artists/3M2S7bYzQt6h4KrnoihzLS',
#        'id': '3M2S7bYzQt6h4KrnoihzLS',
#        'name': 'Tom Russell',
#        'type': 'artist',
#        'uri': 'spotify:artist:3M2S7bYzQt6h4KrnoihzLS'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3r7HtOGFAAqbiK5gSEepmX'},
#      'href': 'https://api.spotify.com/v1/albums/3r7HtOGFAAqbiK5gSEepmX',
#      'id': '3r7HtOGFAAqbiK5gSEepmX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273175362b33320813a70dfb406',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02175362b33320813a70dfb406',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851175362b33320813a70dfb406',
#        'width': 64}],
#      'name': 'Wounded Heart Of America',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:3r7HtOGFAAqbiK5gSEepmX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3M2S7bYzQt6h4KrnoihzLS'},
#       'href': 'https://api.spotify.com/v1/artists/3M2S7bYzQt6h4KrnoihzLS',
#       'id': '3M2S7bYzQt6h4KrnoihzLS',
#       'name': 'Tom Russell',
#       'type': 'artist',
#       'uri': 'spotify:artist:3M2S7bYzQt6h4KrnoihzLS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/763opp15PhfHpEaiVjM6m7'},
#       'href': 'https://api.spotify.com/v1/artists/763opp15PhfHpEaiVjM6m7',
#       'id': '763opp15PhfHpEaiVjM6m7',
#       'name': 'Jerry Jeff Walker',
#       'type': 'artist',
#       'uri': 'spotify:artist:763opp15PhfHpEaiVjM6m7'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 181480,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSE90930880'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1MZ7Rfi2PHCK0AF8gxaE2J'},
#     'href': 'https://api.spotify.com/v1/tracks/1MZ7Rfi2PHCK0AF8gxaE2J',
#     'id': '1MZ7Rfi2PHCK0AF8gxaE2J',
#     'is_local': False,
#     'name': 'Navajo Rug',
#     'popularity': 37,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1MZ7Rfi2PHCK0AF8gxaE2J'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20UltlhZa5iKdeQeEpdiX9'},
#        'href': 'https://api.spotify.com/v1/artists/20UltlhZa5iKdeQeEpdiX9',
#        'id': '20UltlhZa5iKdeQeEpdiX9',
#        'name': 'Ian Tyson',
#        'type': 'artist',
#        'uri': 'spotify:artist:20UltlhZa5iKdeQeEpdiX9'}],
#      'available_markets': ['AE',
#       'AR',
#       'AU',
#       'BH',
#       'BO',
#       'BR',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'DZ',
#       'EC',
#       'EG',
#       'GT',
#       'HK',
#       'HN',
#       'ID',
#       'IN',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'MA',
#       'MD',
#       'MX',
#       'MY',
#       'NI',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PS',
#       'PY',
#       'QA',
#       'SA',
#       'SG',
#       'SV',
#       'TH',
#       'TN',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Jbgivex2idqaLLsn5L270'},
#      'href': 'https://api.spotify.com/v1/albums/2Jbgivex2idqaLLsn5L270',
#      'id': '2Jbgivex2idqaLLsn5L270',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739a3207c754a1cba2a2fa496b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029a3207c754a1cba2a2fa496b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519a3207c754a1cba2a2fa496b',
#        'width': 64}],
#      'name': 'Cowboyography',
#      'release_date': '1987',
#      'release_date_precision': 'year',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2Jbgivex2idqaLLsn5L270'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20UltlhZa5iKdeQeEpdiX9'},
#       'href': 'https://api.spotify.com/v1/artists/20UltlhZa5iKdeQeEpdiX9',
#       'id': '20UltlhZa5iKdeQeEpdiX9',
#       'name': 'Ian Tyson',
#       'type': 'artist',
#       'uri': 'spotify:artist:20UltlhZa5iKdeQeEpdiX9'}],
#     'available_markets': ['AE',
#      'AR',
#      'AU',
#      'BH',
#      'BO',
#      'BR',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'DZ',
#      'EC',
#      'EG',
#      'GT',
#      'HK',
#      'HN',
#      'ID',
#      'IN',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'MA',
#      'MD',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PS',
#      'PY',
#      'QA',
#      'SA',
#      'SG',
#      'SV',
#      'TH',
#      'TN',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 174000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USVG29653234'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Jcn96seSoIqwrNPvvO6Fu'},
#     'href': 'https://api.spotify.com/v1/tracks/2Jcn96seSoIqwrNPvvO6Fu',
#     'id': '2Jcn96seSoIqwrNPvvO6Fu',
#     'is_local': False,
#     'name': 'Navajo Rug',
#     'popularity': 35,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2Jcn96seSoIqwrNPvvO6Fu'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/763opp15PhfHpEaiVjM6m7'},
#        'href': 'https://api.spotify.com/v1/artists/763opp15PhfHpEaiVjM6m7',
#        'id': '763opp15PhfHpEaiVjM6m7',
#        'name': 'Jerry Jeff Walker',
#        'type': 'artist',
#        'uri': 'spotify:artist:763opp15PhfHpEaiVjM6m7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19T9JTF2Mv5GZ0VOD2LERO'},
#      'href': 'https://api.spotify.com/v1/albums/19T9JTF2Mv5GZ0VOD2LERO',
#      'id': '19T9JTF2Mv5GZ0VOD2LERO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c05c2cc628b750d4b6b1e9e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c05c2cc628b750d4b6b1e9e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c05c2cc628b750d4b6b1e9e',
#        'width': 64}],
#      'name': 'Best Of The Rest Vol. 1',
#      'release_date': '2006-07-06',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:19T9JTF2Mv5GZ0VOD2LERO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/763opp15PhfHpEaiVjM6m7'},
#       'href': 'https://api.spotify.com/v1/artists/763opp15PhfHpEaiVjM6m7',
#       'id': '763opp15PhfHpEaiVjM6m7',
#       'name': 'Jerry Jeff Walker',
#       'type': 'artist',
#       'uri': 'spotify:artist:763opp15PhfHpEaiVjM6m7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 182000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USPBR0502552'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ByuQOTtjlkyivxAwLyRsN'},
#     'href': 'https://api.spotify.com/v1/tracks/0ByuQOTtjlkyivxAwLyRsN',
#     'id': '0ByuQOTtjlkyivxAwLyRsN',
#     'is_local': False,
#     'name': 'Navajo Rug',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9bd8dc3fde0c78d30ba30f044d8dc5523ac0c8ca?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ByuQOTtjlkyivxAwLyRsN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45vs9Drn5QbWAQ4Kff6ofh'},
#        'href': 'https://api.spotify.com/v1/artists/45vs9Drn5QbWAQ4Kff6ofh',
#        'id': '45vs9Drn5QbWAQ4Kff6ofh',
#        'name': 'Old & In The Way',
#        'type': 'artist',
#        'uri': 'spotify:artist:45vs9Drn5QbWAQ4Kff6ofh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3J6GgM239l7FkgsuYwmIvF'},
#      'href': 'https://api.spotify.com/v1/albums/3J6GgM239l7FkgsuYwmIvF',
#      'id': '3J6GgM239l7FkgsuYwmIvF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273125a8462053d7d41779c1c28',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02125a8462053d7d41779c1c28',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851125a8462053d7d41779c1c28',
#        'width': 64}],
#      'name': 'The Complete Boarding House Shows',
#      'release_date': '2013-10-29',
#      'release_date_precision': 'day',
#      'total_tracks': 55,
#      'type': 'album',
#      'uri': 'spotify:album:3J6GgM239l7FkgsuYwmIvF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45vs9Drn5QbWAQ4Kff6ofh'},
#       'href': 'https://api.spotify.com/v1/artists/45vs9Drn5QbWAQ4Kff6ofh',
#       'id': '45vs9Drn5QbWAQ4Kff6ofh',
#       'name': 'Old & In The Way',
#       'type': 'artist',
#       'uri': 'spotify:artist:45vs9Drn5QbWAQ4Kff6ofh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 441493,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAD41300032'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ITgWlmq7WLBruDqwewjUb'},
#     'href': 'https://api.spotify.com/v1/tracks/3ITgWlmq7WLBruDqwewjUb',
#     'id': '3ITgWlmq7WLBruDqwewjUb',
#     'is_local': False,
#     'name': 'Land of the Navajo',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2fe369c7a6d73473b6431b2b68d4b855a577d2e0?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3ITgWlmq7WLBruDqwewjUb'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NCGI6dLTxLdI9XHdv7QfM'},
#        'href': 'https://api.spotify.com/v1/artists/2NCGI6dLTxLdI9XHdv7QfM',
#        'id': '2NCGI6dLTxLdI9XHdv7QfM',
#        'name': 'The Andrews Sisters',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NCGI6dLTxLdI9XHdv7QfM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3GK2W9eAOQ6585VCGKvKkh'},
#      'href': 'https://api.spotify.com/v1/albums/3GK2W9eAOQ6585VCGKvKkh',
#      'id': '3GK2W9eAOQ6585VCGKvKkh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735dce3390d208e9ad03c3632d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025dce3390d208e9ad03c3632d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515dce3390d208e9ad03c3632d',
#        'width': 64}],
#      'name': 'Their Greatest Hits And Finest Performances',
#      'release_date': '1996-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 60,
#      'type': 'album',
#      'uri': 'spotify:album:3GK2W9eAOQ6585VCGKvKkh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZjFtWeHP9XN7FeKSUe80S'},
#       'href': 'https://api.spotify.com/v1/artists/6ZjFtWeHP9XN7FeKSUe80S',
#       'id': '6ZjFtWeHP9XN7FeKSUe80S',
#       'name': 'Bing Crosby',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZjFtWeHP9XN7FeKSUe80S'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2NCGI6dLTxLdI9XHdv7QfM'},
#       'href': 'https://api.spotify.com/v1/artists/2NCGI6dLTxLdI9XHdv7QfM',
#       'id': '2NCGI6dLTxLdI9XHdv7QfM',
#       'name': 'The Andrews Sisters',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NCGI6dLTxLdI9XHdv7QfM'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wHn4S5C2d5fqXIPnJWe42'},
#       'href': 'https://api.spotify.com/v1/artists/5wHn4S5C2d5fqXIPnJWe42',
#       'id': '5wHn4S5C2d5fqXIPnJWe42',
#       'name': 'Vic Schoen & His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wHn4S5C2d5fqXIPnJWe42'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 165933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC14550864'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1FnoA5TrjMhKRperQcZFWg'},
#     'href': 'https://api.spotify.com/v1/tracks/1FnoA5TrjMhKRperQcZFWg',
#     'id': '1FnoA5TrjMhKRperQcZFWg',
#     'is_local': False,
#     'name': 'Along The Navajo Trail',
#     'popularity': 34,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1FnoA5TrjMhKRperQcZFWg'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34cyMT4oXZ7lZewjC3f9Ow'},
#      'href': 'https://api.spotify.com/v1/albums/34cyMT4oXZ7lZewjC3f9Ow',
#      'id': '34cyMT4oXZ7lZewjC3f9Ow',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5307162eeffef81f744316d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5307162eeffef81f744316d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5307162eeffef81f744316d',
#        'width': 64}],
#      'name': 'Vol 2 Best of the Native Land',
#      'release_date': '2013-01-14',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:34cyMT4oXZ7lZewjC3f9Ow'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18yiRgR9PlDfN70WQT6s1C'},
#       'href': 'https://api.spotify.com/v1/artists/18yiRgR9PlDfN70WQT6s1C',
#       'id': '18yiRgR9PlDfN70WQT6s1C',
#       'name': 'Apache Spirit',
#       'type': 'artist',
#       'uri': 'spotify:artist:18yiRgR9PlDfN70WQT6s1C'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 236573,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCABL1359644'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/309ecLXei23s4uA4kaOuqc'},
#     'href': 'https://api.spotify.com/v1/tracks/309ecLXei23s4uA4kaOuqc',
#     'id': '309ecLXei23s4uA4kaOuqc',
#     'is_local': False,
#     'name': 'Sweet Navajo Love (Chelly Pub-Bmi)',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/144589565d9a538bc00f02d69df0b05fe568975c?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:309ecLXei23s4uA4kaOuqc'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nIUhcKHnK6iyumRyoV68C'},
#        'href': 'https://api.spotify.com/v1/artists/1nIUhcKHnK6iyumRyoV68C',
#        'id': '1nIUhcKHnK6iyumRyoV68C',
#        'name': 'Ennio Morricone',
#        'type': 'artist',
#        'uri': 'spotify:artist:1nIUhcKHnK6iyumRyoV68C'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1q4tU5lDRLboe996a2TRYR'},
#      'href': 'https://api.spotify.com/v1/albums/1q4tU5lDRLboe996a2TRYR',
#      'id': '1q4tU5lDRLboe996a2TRYR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c9e5f503660bfe643afd7ef6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c9e5f503660bfe643afd7ef6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c9e5f503660bfe643afd7ef6',
#        'width': 64}],
#      'name': "Un' Ora Con Ennio Morricone",
#      'release_date': '1966',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:1q4tU5lDRLboe996a2TRYR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nIUhcKHnK6iyumRyoV68C'},
#       'href': 'https://api.spotify.com/v1/artists/1nIUhcKHnK6iyumRyoV68C',
#       'id': '1nIUhcKHnK6iyumRyoV68C',
#       'name': 'Ennio Morricone',
#       'type': 'artist',
#       'uri': 'spotify:artist:1nIUhcKHnK6iyumRyoV68C'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 171200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA370636693'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ZFg1vTdreiZNg4T4m4HM2'},
#     'href': 'https://api.spotify.com/v1/tracks/6ZFg1vTdreiZNg4T4m4HM2',
#     'id': '6ZFg1vTdreiZNg4T4m4HM2',
#     'is_local': False,
#     'name': 'Navajo Joe',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/addebe52a80bd3edbd1cf9ddedf3f06588f79d98?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6ZFg1vTdreiZNg4T4m4HM2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35C0NSLogAwImm8HAMqEmG'},
#        'href': 'https://api.spotify.com/v1/artists/35C0NSLogAwImm8HAMqEmG',
#        'id': '35C0NSLogAwImm8HAMqEmG',
#        'name': 'Black Lips',
#        'type': 'artist',
#        'uri': 'spotify:artist:35C0NSLogAwImm8HAMqEmG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6sDyIpIg0vjpKOR9VrvagJ'},
#      'href': 'https://api.spotify.com/v1/albums/6sDyIpIg0vjpKOR9VrvagJ',
#      'id': '6sDyIpIg0vjpKOR9VrvagJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d8a0a4c940cc5a910a2adc7d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d8a0a4c940cc5a910a2adc7d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d8a0a4c940cc5a910a2adc7d',
#        'width': 64}],
#      'name': 'Good Bad Not Evil',
#      'release_date': '2007-09-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6sDyIpIg0vjpKOR9VrvagJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35C0NSLogAwImm8HAMqEmG'},
#       'href': 'https://api.spotify.com/v1/artists/35C0NSLogAwImm8HAMqEmG',
#       'id': '35C0NSLogAwImm8HAMqEmG',
#       'name': 'Black Lips',
#       'type': 'artist',
#       'uri': 'spotify:artist:35C0NSLogAwImm8HAMqEmG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 161026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USALX0500969'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7opsuIOW3s6e4vfXj6PIo8'},
#     'href': 'https://api.spotify.com/v1/tracks/7opsuIOW3s6e4vfXj6PIo8',
#     'id': '7opsuIOW3s6e4vfXj6PIo8',
#     'is_local': False,
#     'name': 'Navajo',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cc9cc4fc7d59d4d33aae0385e6f92bbb7607ccc7?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7opsuIOW3s6e4vfXj6PIo8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YzqTtLHLII6iCqiluKPPx'},
#        'href': 'https://api.spotify.com/v1/artists/2YzqTtLHLII6iCqiluKPPx',
#        'id': '2YzqTtLHLII6iCqiluKPPx',
#        'name': 'Zamfir',
#        'type': 'artist',
#        'uri': 'spotify:artist:2YzqTtLHLII6iCqiluKPPx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5KYZtxIJAEFc4ahwgtptQQ'},
#      'href': 'https://api.spotify.com/v1/albums/5KYZtxIJAEFc4ahwgtptQQ',
#      'id': '5KYZtxIJAEFc4ahwgtptQQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739c83564d08f7e7d848f44d59',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029c83564d08f7e7d848f44d59',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519c83564d08f7e7d848f44d59',
#        'width': 64}],
#      'name': 'Blue Navajo',
#      'release_date': '2010-10-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5KYZtxIJAEFc4ahwgtptQQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12FFWdcxApUNXV9TljwDpT'},
#       'href': 'https://api.spotify.com/v1/artists/12FFWdcxApUNXV9TljwDpT',
#       'id': '12FFWdcxApUNXV9TljwDpT',
#       'name': 'Gheorghe Zamfir',
#       'type': 'artist',
#       'uri': 'spotify:artist:12FFWdcxApUNXV9TljwDpT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 213617,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEF458043192'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3aMkSlWZcFMwfXYGIskbkK'},
#     'href': 'https://api.spotify.com/v1/tracks/3aMkSlWZcFMwfXYGIskbkK',
#     'id': '3aMkSlWZcFMwfXYGIskbkK',
#     'is_local': False,
#     'name': 'Blue Navajo',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca55f6fd3b4fd7404dd43422e800a67f572e0413?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3aMkSlWZcFMwfXYGIskbkK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT'},
#        'href': 'https://api.spotify.com/v1/artists/6zvul52xwTWzilBZl6BUbT',
#        'id': '6zvul52xwTWzilBZl6BUbT',
#        'name': 'Pixies',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zvul52xwTWzilBZl6BUbT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1xtaONLuwdb5STNnLGNVGi'},
#      'href': 'https://api.spotify.com/v1/albums/1xtaONLuwdb5STNnLGNVGi',
#      'id': '1xtaONLuwdb5STNnLGNVGi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad2c2f87613b6e2115d2babb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad2c2f87613b6e2115d2babb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad2c2f87613b6e2115d2babb',
#        'width': 64}],
#      'name': 'Trompe le Monde',
#      'release_date': '1991-09-23',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1xtaONLuwdb5STNnLGNVGi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT'},
#       'href': 'https://api.spotify.com/v1/artists/6zvul52xwTWzilBZl6BUbT',
#       'id': '6zvul52xwTWzilBZl6BUbT',
#       'name': 'Pixies',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zvul52xwTWzilBZl6BUbT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 139826,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAFL9100112'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3SB6kF6hp9XGugddEmjz16'},
#     'href': 'https://api.spotify.com/v1/tracks/3SB6kF6hp9XGugddEmjz16',
#     'id': '3SB6kF6hp9XGugddEmjz16',
#     'is_local': False,
#     'name': 'The Navajo Know',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/67be9aac18e4c426dd3311ba625906d9ac5cac61?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:3SB6kF6hp9XGugddEmjz16'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/763opp15PhfHpEaiVjM6m7'},
#        'href': 'https://api.spotify.com/v1/artists/763opp15PhfHpEaiVjM6m7',
#        'id': '763opp15PhfHpEaiVjM6m7',
#        'name': 'Jerry Jeff Walker',
#        'type': 'artist',
#        'uri': 'spotify:artist:763opp15PhfHpEaiVjM6m7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1MWxYVWUwjz2LewfkKi3qo'},
#      'href': 'https://api.spotify.com/v1/albums/1MWxYVWUwjz2LewfkKi3qo',
#      'id': '1MWxYVWUwjz2LewfkKi3qo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355fed5567bdee569ca9d74b0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255fed5567bdee569ca9d74b0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155fed5567bdee569ca9d74b0',
#        'width': 64}],
#      'name': 'Navajo Rug',
#      'release_date': '2006-07-06',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1MWxYVWUwjz2LewfkKi3qo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/763opp15PhfHpEaiVjM6m7'},
#       'href': 'https://api.spotify.com/v1/artists/763opp15PhfHpEaiVjM6m7',
#       'id': '763opp15PhfHpEaiVjM6m7',
#       'name': 'Jerry Jeff Walker',
#       'type': 'artist',
#       'uri': 'spotify:artist:763opp15PhfHpEaiVjM6m7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
# ...
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c366ed8c28c3ecf63f0c6f3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c366ed8c28c3ecf63f0c6f3e',
#        'width': 64}],
#      'name': 'Mis XV Años, Vol. 3',
#      'release_date': '2007-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5cfFZ4End3P2JRmEzb2gms'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4pJk87wBW1PnbGRdPWPSzC'},
#       'href': 'https://api.spotify.com/v1/artists/4pJk87wBW1PnbGRdPWPSzC',
#       'id': '4pJk87wBW1PnbGRdPWPSzC',
#       'name': 'Rafael Alejandro',
#       'type': 'artist',
#       'uri': 'spotify:artist:4pJk87wBW1PnbGRdPWPSzC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 177400,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM6DC1547163'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3c5u4WD1JPqBxXGpFGUhFA'},
#     'href': 'https://api.spotify.com/v1/tracks/3c5u4WD1JPqBxXGpFGUhFA',
#     'id': '3c5u4WD1JPqBxXGpFGUhFA',
#     'is_local': False,
#     'name': 'El Navajo Azul',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4e269e4687a3ccbde552902f874b5386de7f9341?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3c5u4WD1JPqBxXGpFGUhFA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Fxwcku7ybQr4azQhK2418'},
#        'href': 'https://api.spotify.com/v1/artists/5Fxwcku7ybQr4azQhK2418',
#        'id': '5Fxwcku7ybQr4azQhK2418',
#        'name': 'Craig Chaquico',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Fxwcku7ybQr4azQhK2418'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7E9HddNY3aKS9sJiLRO9TY'},
#      'href': 'https://api.spotify.com/v1/albums/7E9HddNY3aKS9sJiLRO9TY',
#      'id': '7E9HddNY3aKS9sJiLRO9TY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d2914b2f6a82c1f9b8bb9d7b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d2914b2f6a82c1f9b8bb9d7b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d2914b2f6a82c1f9b8bb9d7b',
#        'width': 64}],
#      'name': 'A Thousand Pictures',
#      'release_date': '1996-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7E9HddNY3aKS9sJiLRO9TY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Fxwcku7ybQr4azQhK2418'},
#       'href': 'https://api.spotify.com/v1/artists/5Fxwcku7ybQr4azQhK2418',
#       'id': '5Fxwcku7ybQr4azQhK2418',
#       'name': 'Craig Chaquico',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Fxwcku7ybQr4azQhK2418'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 380266,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHOM9601003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/59j5hn8ljVDfaJ2QaVeyFW'},
#     'href': 'https://api.spotify.com/v1/tracks/59j5hn8ljVDfaJ2QaVeyFW',
#     'id': '59j5hn8ljVDfaJ2QaVeyFW',
#     'is_local': False,
#     'name': 'Navajo Stars',
#     'popularity': 18,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:59j5hn8ljVDfaJ2QaVeyFW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2D38buglrcCl9TMZ45tkh1'},
#        'href': 'https://api.spotify.com/v1/artists/2D38buglrcCl9TMZ45tkh1',
#        'id': '2D38buglrcCl9TMZ45tkh1',
#        'name': 'R. Carlos Nakai',
#        'type': 'artist',
#        'uri': 'spotify:artist:2D38buglrcCl9TMZ45tkh1'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6U5U0rNdnTCf88dAyCpmjg'},
#        'href': 'https://api.spotify.com/v1/artists/6U5U0rNdnTCf88dAyCpmjg',
#        'id': '6U5U0rNdnTCf88dAyCpmjg',
#        'name': 'William Eaton',
#        'type': 'artist',
#        'uri': 'spotify:artist:6U5U0rNdnTCf88dAyCpmjg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0mMdro5USkKmSwkBXrky9o'},
#      'href': 'https://api.spotify.com/v1/albums/0mMdro5USkKmSwkBXrky9o',
#      'id': '0mMdro5USkKmSwkBXrky9o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aaef49216952eb2c6ca636cd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aaef49216952eb2c6ca636cd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aaef49216952eb2c6ca636cd',
#        'width': 64}],
#      'name': 'Winter Dreams for Christmas',
#      'release_date': '1994-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0mMdro5USkKmSwkBXrky9o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2D38buglrcCl9TMZ45tkh1'},
#       'href': 'https://api.spotify.com/v1/artists/2D38buglrcCl9TMZ45tkh1',
#       'id': '2D38buglrcCl9TMZ45tkh1',
#       'name': 'R. Carlos Nakai',
#       'type': 'artist',
#       'uri': 'spotify:artist:2D38buglrcCl9TMZ45tkh1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6U5U0rNdnTCf88dAyCpmjg'},
#       'href': 'https://api.spotify.com/v1/artists/6U5U0rNdnTCf88dAyCpmjg',
#       'id': '6U5U0rNdnTCf88dAyCpmjg',
#       'name': 'William Eaton',
#       'type': 'artist',
#       'uri': 'spotify:artist:6U5U0rNdnTCf88dAyCpmjg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 310333,
#     'explicit': False,
#     'external_ids': {'isrc': 'US8640570710'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/06cz2ADtQ23yL9mukUiZbq'},
#     'href': 'https://api.spotify.com/v1/tracks/06cz2ADtQ23yL9mukUiZbq',
#     'id': '06cz2ADtQ23yL9mukUiZbq',
#     'is_local': False,
#     'name': 'Silent Night (with Navajo Chorale)',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8a3a98e34559fd207603eca573434f0c31bdd0b8?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:06cz2ADtQ23yL9mukUiZbq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wUajNUxC3hYAbFh9brF9X'},
#        'href': 'https://api.spotify.com/v1/artists/5wUajNUxC3hYAbFh9brF9X',
#        'id': '5wUajNUxC3hYAbFh9brF9X',
#        'name': 'Rachel Feinstein',
#        'type': 'artist',
#        'uri': 'spotify:artist:5wUajNUxC3hYAbFh9brF9X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3YGSkc6OthsDYJAsu0GxHe'},
#      'href': 'https://api.spotify.com/v1/albums/3YGSkc6OthsDYJAsu0GxHe',
#      'id': '3YGSkc6OthsDYJAsu0GxHe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27389268d6ff3dd38ebad046449',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0289268d6ff3dd38ebad046449',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485189268d6ff3dd38ebad046449',
#        'width': 64}],
#      'name': 'Thug Tears',
#      'release_date': '2011-11-21',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:3YGSkc6OthsDYJAsu0GxHe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wUajNUxC3hYAbFh9brF9X'},
#       'href': 'https://api.spotify.com/v1/artists/5wUajNUxC3hYAbFh9brF9X',
#       'id': '5wUajNUxC3hYAbFh9brF9X',
#       'name': 'Rachel Feinstein',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wUajNUxC3hYAbFh9brF9X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 110906,
#     'explicit': True,
#     'external_ids': {'isrc': 'US85P1112306'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ggfP6f9wgRZE6WLAsIfG7'},
#     'href': 'https://api.spotify.com/v1/tracks/4ggfP6f9wgRZE6WLAsIfG7',
#     'id': '4ggfP6f9wgRZE6WLAsIfG7',
#     'is_local': False,
#     'name': 'Navajo graveyard',
#     'popularity': 17,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aa87f7fcce21ea85d62a5ee489cbd1ec3e2b315e?cid=ff2a57c5d38647df96724e1fa79120f4',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4ggfP6f9wgRZE6WLAsIfG7'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3ANavajo&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 833}}

# %%
spotify.get_artist_genres("4sj6D0zlMOl25nprDJBiU9")
# Out:
# ['adult standards', 'easy listening', 'mellow gold']

# %%
#Sign of the Times trackID: 5Ohxk2dO5COHF1krpoPigN (artist is Harry Styles)
spotify.get_track_data("5Ohxk2dO5COHF1krpoPigN")
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#     'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#     'id': '6KImCVD70vtIoJWnq6nGn3',
#     'name': 'Harry Styles',
#     'type': 'artist',
#     'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1FZKIm3JVDCxTchXDo5jOV'},
#   'href': 'https://api.spotify.com/v1/albums/1FZKIm3JVDCxTchXDo5jOV',
#   'id': '1FZKIm3JVDCxTchXDo5jOV',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736c619c39c853f8b1d67b7859',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026c619c39c853f8b1d67b7859',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516c619c39c853f8b1d67b7859',
#     'width': 64}],
#   'name': 'Harry Styles',
#   'release_date': '2017-05-12',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:1FZKIm3JVDCxTchXDo5jOV'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#    'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#    'id': '6KImCVD70vtIoJWnq6nGn3',
#    'name': 'Harry Styles',
#    'type': 'artist',
#    'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'BY',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'disc_number': 1,
#  'duration_ms': 340706,
#  'explicit': False,
#  'external_ids': {'isrc': 'USSM11703595'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5Ohxk2dO5COHF1krpoPigN'},
#  'href': 'https://api.spotify.com/v1/tracks/5Ohxk2dO5COHF1krpoPigN',
#  'id': '5Ohxk2dO5COHF1krpoPigN',
#  'is_local': False,
#  'name': 'Sign of the Times',
#  'popularity': 83,
#  'preview_url': 'https://p.scdn.co/mp3-preview/af237206f611b722f48620ece049aff3b8650e77?cid=ff2a57c5d38647df96724e1fa79120f4',
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:5Ohxk2dO5COHF1krpoPigN'}

# %%
spotify.get_track_artists("5Ohxk2dO5COHF1krpoPigN")
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#   'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#   'id': '6KImCVD70vtIoJWnq6nGn3',
#   'name': 'Harry Styles',
#   'type': 'artist',
#   'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}]

# %%
spotify.get_track_artists_id("5Ohxk2dO5COHF1krpoPigN")
# Out:
# '6KImCVD70vtIoJWnq6nGn3'

# %%
spotify.get_track_audio_features("5Ohxk2dO5COHF1krpoPigN")
# Out:
# {'danceability': 0.516,
#  'energy': 0.595,
#  'key': 5,
#  'loudness': -4.63,
#  'mode': 1,
#  'speechiness': 0.0313,
#  'acousticness': 0.0275,
#  'instrumentalness': 0,
#  'liveness': 0.109,
#  'valence': 0.222,
#  'tempo': 119.972,
#  'type': 'audio_features',
#  'id': '5Ohxk2dO5COHF1krpoPigN',
#  'uri': 'spotify:track:5Ohxk2dO5COHF1krpoPigN',
#  'track_href': 'https://api.spotify.com/v1/tracks/5Ohxk2dO5COHF1krpoPigN',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Ohxk2dO5COHF1krpoPigN',
#  'duration_ms': 340707,
#  'time_signature': 4}

# %%
spotify.get_track_specific_audio_feature("5Ohxk2dO5COHF1krpoPigN", specific_audio_feature='valence')
# Out:
# 0.222

# %%
#multiple artists test case
#1RUubW9fHtIYwjl588PrhZ - https://open.spotify.com/album/0lrmy4pJINsFzycJvttX2W?highlight=spotify:track:1RUubW9fHtIYwjl588PrhZ

spotify.get_track_artists("1RUubW9fHtIYwjl588PrhZ")
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#   'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#   'id': '2RdwBSPQiwcmiDo9kixcl8',
#   'name': 'Pharrell Williams',
#   'type': 'artist',
#   'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#   'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#   'id': '31TPClRtHm23RisEBtV3X7',
#   'name': 'Justin Timberlake',
#   'type': 'artist',
#   'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}]

# %%
#TRACK INFO FOR API FETCHING#

##NON_CSV STUFF##

###COLUMNS FOR SHOWING info in FRONT END###
#explicit
#popularity

##CSV STUFF##

###COLUMNS FOR AUDIO FEATURES IN TRAINING DATA CSV### 
##(accessible via method: get_track_specific_audio_feature(self, _id, specific_audio_feature='tempo'))
#valence
#acousticness
#danceability
#duration_ms
#energy
#instrumentalness
#key
#liveliness
#loudness
#mode
#speechiness
#tempo

###other info in TRAINING DATA CSV###
#id ((###PRIMARY###))
#name
#year
#explicit
#popularity
#release_date
